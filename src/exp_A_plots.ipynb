# %%
import importlib
import matplotlib.pyplot as plt
from utils import test_combinations, plot_results
from load_embeddings import load_embedding_model
from wordlist import mammals, birds, colors, fruits
import json
import os

importlib.reload(utils)#this makes sure that any changes to the file are imported
importlib.reload(load_embeddings)

# model, tokenizer = load_embedding_model(
#     151936, 1536,
#     "embeddings_qwen.pth",
#     "unembeddings_qwen.pth",
#     "deepseek-ai/DeepSeek-R1-Distill-Qwen-1.5B"
# )
vocab_size = 151936
dimensions = 1536
project_dir = os.path.dirname(__file__)[:-3]

# %%
model, tokenizer = load_embedding_model(
    vocab_size,
    dimensions,
    f"{project_dir}/models/embeddings_qwen.pth",
    f"{project_dir}/models/unembedding_qwen.pth",
    "deepseek-ai/DeepSeek-R1-Distill-Qwen-1.5B"
)
model.eval()
